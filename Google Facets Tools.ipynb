# %% [markdown]
# # Setup
#
# - The below example shows a way in which you can implement the Google Facet tool to dive into your data for analytical purposes
# - In this example you can explore both the option of Dive and Overview, both different ways of analysing and seeing your dataset
# - If you want to use your own dataset change the directory given for variable 'dataset_dir' to the relevant directory of your dataset
# - When changing the directory, ensure your data is in the "dataset" folder and that your data is a CSV format. Change directory to -> 'dataset/yourcsvfilename.csv'

# %%
import pandas as pd
import base64
from sklearn.model_selection import train_test_split
from IPython.display import display, HTML, clear_output

from facets_overview.generic_feature_statistics_generator import GenericFeatureStatisticsGenerator

# %%
clear_output()

# %%
dataset_dir = 'dataset/MCD_survey_data.csv'
dataset = pd.read_csv(dataset_dir)

features = ["first_name", "last_name", "age", "country", "favorite_color", "frequency_of_visits", "favorite_menu_item", "employment_status", "Gender"] # Select features you'd like to have included in your train & test dataset .
dataset = dataset[features]                                                                                                                             # If you wish to keep all data you do not require this step.

# %%
train_dataset, test_dataset = train_test_split(dataset, test_size=0.33, random_state=42)

# %%
# Display the Dive visualization for the training data.

def dive(train_dataset, test_dataset):
    clear_output()
    jsonstr = train_dataset.to_json(orient='records')
    HTML_TEMPLATE = """
            <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
            <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
            <facets-dive id="elem" height="600"></facets-dive>
            <script>
              var data = {jsonstr};
              document.querySelector("#elem").data = data;
            </script>"""
    html = HTML_TEMPLATE.format(jsonstr=jsonstr)
    return html

def overview(train_dataset,test_dataset):
    clear_output()
    gfsg = GenericFeatureStatisticsGenerator()
    proto = gfsg.ProtoFromDataFrames([{'name': 'train', 'table': train_dataset},
                                      {'name': 'test', 'table': test_dataset}])
    protostr = base64.b64encode(proto.SerializeToString()).decode("utf-8")

    HTML_TEMPLATE2 = """
            <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
            <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html" >
            <facets-overview id="elem"></facets-overview>
            <script>
              document.querySelector("#elem").protoInput = "{protostr}";
            </script>"""
    html = HTML_TEMPLATE2.format(protostr=protostr)
    return html

# %% [markdown]
# # How to use

# %% [markdown]
# ## In order to use the Google Facets Tool, follow the below steps:
#
#     - Insert or use a new cell bellow. To insert a new cell click into a cell, press ESC then double tap 'B' twice to create a cell bellow.
#     - If you need to remove a cell - click cell -> Press ESC -> Double click 'D'
#
#     - Once a new cell is insert use the following code to view a 'dive' Facet on your dataset:
#         """
#         html = dive(train_dataset,test_dataset)
#         display(HTML(html))
#         """
#
#     - Use the following code to view an 'overview' on your dataset:
#         """
#         html = overview(train_dataset,test_dataset)
#         display(HTML(html))
#         """
#
#     # IMPORTANT NOTICE!
#     Once you have completed using either of the two options, ensure that you delete the cell you were using by pressing ESC -> Double press 'D'. Jupyter Studio does not allow for two cells to be running visuals at the same time, ONLY USE ONE AT A TIME.
#     If any of the views when used singularly cause issues, ensure that you have saved your notebook and refresh the page; this will fix any issues with viewing
#     ENSURE YOU USE LIGHT MODE WHEN USING THIS TOOL.
#     Change mode by navigating to -> Settings -> Theme -> JupyterLab Light

# %%
html = dive(train_dataset,test_dataset)
display(HTML(html))
# Out:
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#             <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html">
#             <facets-dive id="elem" height="600"></facets-dive>
#             <script>
#               var data = [{"first_name":"Janith","last_name":"Froment","age":31,"country":"France","favorite_color":"blue","frequency_of_visits":0.9,"favorite_menu_item":"McNuggets","employment_status":"Full-time","Gender":"Female"},{"first_name":"Darcy","last_name":"Rentoll","age":20,"country":"China","favorite_color":"red","frequency_of_visits":4.4,"favorite_menu_item":"McNuggets","employment_status":"Retired","Gender":"Male"},{"first_name":"Cheryl","last_name":"Heam","age":85,"country":"Sweden","favorite_color":"blue","frequency_of_visits":4.3,"favorite_menu_item":"Big Mac","employment_status":"Student","Gender":"Female"},{"first_name":"Scotty","last_name":"Ivanov","age":26,"country":"Indonesia","favorite_color":"red","frequency_of_visits":4.2,"favorite_menu_item":"Big Mac","employment_status":"Student","Gender":"Male"},{"first_name":"Basilius","last_name":"Atcheson","age":37,"country":"Vietnam","favorite_color":"red","frequency_of_visits":4.4,"favorite_menu_item":"Big Mac","employment_status":"Full-time","Gender":"Male"},{"first_name":"Elicia","last_name":"Chinnery","age":34,"country":"Myanmar","favorite_color":"red","frequency_of_visits":5.2,"favorite_menu_item":"Big Mac","employment_status":"Full-time","Gender":"Female"},{"first_name":"Ethelbert","last_name":"Bunston","age":78,"country":"China","favorite_color":"red","frequency_of_visits":0.2,"favorite_menu_item":"Quarter Pounder","employment_status":"Part-time","Gender":"Male"},{"first_name":"Shelley","last_name":"Flode","age":25,"country":"Indonesia","favorite_color":"blue","frequency_of_visits":0.6,"favorite_menu_item":"McNuggets","employment_status":"Full-time","Gender":"Female"},{"first_name":"Gabie","last_name":"McFadzean","age":64,"country":"Indonesia","favorite_color":"blue","frequency_of_visits":3.8,"favorite_menu_item":"Quarter Pounder","employment_status":"Student","Gender":"Female"},{"first_name":"Cordelie","last_name":"Adam","age":30,"country":"Portugal","favorite_color":"red","frequency_of_visits":1.1,"favorite_menu_item":"Big Mac","employment_status":"Part-time","Gender":"Female"},{"first_name":"Hermione","last_name":"Horlick","age":85,"country":"Gambia","favorite_color":"red","frequency_of_visits":4.5,"favorite_menu_item":"Big Mac","employment_status":"Full-time","Gender":"Female"},{"first_name":"Cyndy","last_name":"Gosselin","age":68,"country":"Indonesia","favorite_color":"green","frequency_of_visits":5.3,"favorite_menu_item":"Big Mac","employment_status":"Retired","Gender":"Female"},{"first_name":"Antonie","last_name":"Goodenough","age":24,"country":"Indonesia","favorite_color":"blue","frequency_of_visits":1.5,"favorite_menu_item":"McNuggets","employment_status":"Student","Gender":"Female"},{"first_name":"Candice","last_name":"Osbourne","age":58,"country":"Brazil","favorite_color":"red","frequency_of_visits":5.4,"favorite_menu_item":"Big Mac","employment_status":"Part-time","Gender":"Female"},{"first_name":"Ingaberg","last_name":"Girogetti","age":26,"country":"Indonesia","favorite_color":"red","frequency_of_visits":3.7,"favorite_menu_item":"McNuggets","employment_status":"Retired","Gender":"Female"},{"first_name":"Franchot","last_name":"McFfaden","age":57,"country":"Democratic Republic of the Congo","favorite_color":"red","frequency_of_visits":2.8,"favorite_menu_item":"Big Mac","employment_status":"Full-time","Gender":"Male"},{"first_name":"Chrysler","last_name":"Quinane","age":41,"country":"Georgia","favorite_color":"red","frequency_of_visits":1.1,"favorite_menu_item":"McNuggets","employment_status":"Retired","Gender":"Female"},{"first_name":"Florri","last_name":"Eckels","age":38,"country":"Russia","favorite_color":"blue","frequency_of_visits":3.8,"favorite_menu_item":"Big Mac","employment_status":"Student","Gender":"Female"},{"first_name":"Ruby","last_name":"Priditt","age":33,"country":"Brazil","favorite_color":"red","frequency_of_visits":0.3,"favorite_menu_item":"Quarter Pounder","employment_status":"Part-time","Gender":"Female"},{"first_name":"Laure ...
